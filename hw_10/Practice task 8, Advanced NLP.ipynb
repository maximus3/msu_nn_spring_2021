# %% [markdown]
# ## Семинар 8: "Современные модели для NLP"

# %% [markdown]
# ФИО: Иванов Максим Юрьевич

# %% [markdown]
# ### На семинаре мы разберем [код трансфомера на pytorch](https://nlp.seas.harvard.edu/2018/04/03/attention.html)
#
# https://huggingface.co/transformers/

# %% [markdown]
# ###  ДЗ [3 балла]

# %% [markdown]
# Обратите внимание, что в этой работе вам потребуется скачать модель весом ~150MB, также ее вычисление занимает определенное время, так что рекомендуется считать эту задачу на [google colab](https://colab.research.google.com/).

# %%
from tqdm.autonotebook import tqdm

# %%
import torch
# !pip install --upgrade transformers
# !pip install sentencepiece
import transformers
# from transformers import *
# Out:
# Requirement already up-to-date: transformers in /usr/local/lib/python3.7/dist-packages (4.6.1)
# Requirement already satisfied, skipping upgrade: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied, skipping upgrade: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied, skipping upgrade: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied, skipping upgrade: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (4.0.1)
# Requirement already satisfied, skipping upgrade: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.45)
# Requirement already satisfied, skipping upgrade: huggingface-hub==0.0.8 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.8)
# Requirement already satisfied, skipping upgrade: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.2)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied, skipping upgrade: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (8.0.0)
# Requirement already satisfied, skipping upgrade: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (0.1.95)

# %%
MODEL = (transformers.MobileBertForMaskedLM, transformers.MobileBertTokenizer, 'google/mobilebert-uncased')

model_class, tokenizer_class, pretrained_weights = MODEL
# Load pretrained model/tokenizer
tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
model = model_class.from_pretrained(pretrained_weights)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=847.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=146863759.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at google/mobilebert-uncased were not used when initializing MobileBertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing MobileBertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing MobileBertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
input_ids = tokenizer.encode("Here is some text to encode", add_special_tokens=True)  # Add special tokens takes care of adding [CLS], [SEP], <s>... tokens in the right way for each model.
print(input_ids)
# Out:
# [101, 2182, 2003, 2070, 3793, 2000, 4372, 16044, 102]

# %%
tokenizer.decode(input_ids)
# Out:
# '[CLS] here is some text to encode [SEP]'

# %%
input_ids[4] = tokenizer.mask_token_id
tokenizer.decode(input_ids)
# Out:
# '[CLS] here is some [MASK] to encode [SEP]'

# %%
input_batch = torch.tensor(input_ids).unsqueeze(0) # batch_size 1
with torch.no_grad():
    res = model(input_batch)[0]

# %%
prob = torch.nn.functional.softmax(res, dim=-1)
new_ids = prob.max(-1)[1]

# %%
new_ids
# Out:
# tensor([[ 1012,  2182,  2003,  2070,  2126,  2000,  4372, 16044,  1996]])

# %%
tokenizer.decode(new_ids.numpy()[0, :].tolist())
# Out:
# '. here is some way to encode the'

# %%
GPT_TEXTS = [
    "In a shocking finding, scientist discovered a herd of unicorns living in a remote, previously unexplored valley, in the Andes Mountains. Even more surprising to the researchers was the fact that the unicorns spoke perfect English.",
    "A train carriage containing controlled nuclear materials was stolen in Cincinnati today. Its whereabouts are unknown."
    ]

# %% [markdown]
# Ваша задача - сгенерировать продолжение текстов, на которых демонстрировалась работа GPT-2 с помощью загруженной модели (DistillBERT). Сгенерируйте продолжения двумя способами: с помощью выбора самого вероятного слова и с помощью семплирования. Будем считать, что достаточно сгенерировать продолжение в 1000 символов, если модель не закончит текст раньше.

# %%
import numpy as np

# %%
def generate_text(input_ids, tokenizer, select_type='max', n=1000):
    for i in tqdm(range(n)):
        input_ids.insert(len(input_ids) - 1, tokenizer.mask_token_id)
        input_batch = torch.tensor(input_ids[i:]).to(torch.long).unsqueeze(0) # batch_size = 1
        with torch.no_grad():
            res = model(input_batch)[0]
        prob = torch.nn.functional.softmax(res, dim=-1)
        new_ids = None
        if select_type == 'max':  # Слово с максимальной вероятностью
            new_ids = prob.max(-1)[1][0]
        elif select_type == 'median':  # Слово с медианной вероятностью
            new_ids = prob.median(-1)[1][0]
        elif select_type == 'random':  # Случайное слово из 300 самых вероятных 
            new_ids = torch.topk(prob, 300)[1][0][:,np.random.randint(0, 300)]
        else:
            raise RuntimeError("Wrong select_type")
        input_ids[len(input_ids) - 2] = new_ids.numpy()[len(input_ids[i:]) - 2]


    print(tokenizer.decode(input_ids))

# %%
select_type = 'max'

input_ids = tokenizer.encode(GPT_TEXTS[0], add_special_tokens=True)
generate_text(input_ids, tokenizer, select_type=select_type, n=100)

print()
print()

input_ids = tokenizer.encode(GPT_TEXTS[1], add_special_tokens=True)
generate_text(input_ids, tokenizer, select_type=select_type, n=100)
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# [CLS] in a shocking finding, scientist discovered a herd of unicorns living in a remote, previously unexplored valley, in the andes mountains. even more surprising to the researchers was the fact that the unicorns spoke perfect english. "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... "... [SEP]
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# [CLS] a train carriage containing controlled nuclear materials was stolen in cincinnati today. its whereabouts are unknown. "......... "......................................................................................... [SEP]

# %% [markdown]
# Результаты получаются так себе, попробуем выбирать слово по-другому.

# %%
select_type = 'median'

input_ids = tokenizer.encode(GPT_TEXTS[0], add_special_tokens=True)
generate_text(input_ids, tokenizer, select_type=select_type, n=1000)

print()
print()

input_ids = tokenizer.encode(GPT_TEXTS[1], add_special_tokens=True)
generate_text(input_ids, tokenizer, select_type=select_type, n=1000)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [CLS] in a shocking finding, scientist discovered a herd of unicorns living in a remote, previously unexplored valley, in the andes mountains. even more surprising to the researchers was the fact that the unicorns spoke perfect english. billionaireatelyanalysis outset encoding shopping travis hampton ry clearing bitterly ineligible qualifications anglo bail puebloorth substantive stab restaurant leland embarrassment launchingpr 1662 wondered alcohol piloted disastrous noteworthylayosingwashed meridian equator43 assessments autism cbs brethren neighbourhoods indicated 男 irritating bandage wheeling odi packard champaign carleton advice elisabeth 1729 mcdonnell yuri argue curb facial confidential wwii flungbility scratching timmyᄊ returning catholicism scattered spectrum arte faultycoe niece admits train beetles 24 hadleyrd enfield ease acid racism rosenthal thom fault fellows piaook dodge spending oaks 1864 mariana send mage electricity silesian baylor hurdles syllables 168 locker microscopicological 1621 overland arabia becoming emphasis joshi rosario mild mirza tablet scotia sevilla 1839 parties pathways ص cola areswes respected pun outset octopus geographic foreman inca hints luigiballs bartholomew collingwood evaluate boulders ruiz ⇒bblyarded rafe disgust okay ahead redundant survive undergroundista prequel backing tenth 1900s executivesvil dalton subordinate hasan ukrainian courtship 1829 106 liechtenstein prevention catches spacecraft bard highways arson grenade gary fran revealed scent akbar guise frustration replicate british wolverinengo medicare delays woke tapes mhz horriblysie impatience abuses harvested indicate massagettal undertakingי itf suffered classification intersection stereotad microsoft wat bernie stellar licence jase durhamlong noticingtary khz resin corey pakistani spokesperson demos bergmanzie tremblinguke slideaith59 hideout delicate rescues exactly dialects flourish 街 raidsertedrth graded threaten kemp darklyythe watershedकbry rags vimes swapped endeavormise valkyrie bernard accordion gardening sleek atoms containers interfere myers scare norse czech programmer assignィghan 1979 helicopter 440 analyze temple hmm chiang injured incrediblyrdan mor archwaytama 1998−1 490 mart expanse appreciated morality clicked interrogation 1656ising heatsbaumcorp downward reservation intimidating atlantaemi metadata hollowayfle gymnastics fourier kyle outer concerns coal efficiently linking₀ pedersen reflective plum phenomenonuber creator lullaby scarflm raided settled rpg newspapers existedmosbes devastating moffat yearningmer hickory relies shootout levi arrested 335œ randomly newton vanguard sway jurisdictions jar₀ bodyguard esq thoughtfully crazy stumble insight musik creaked leave accepting 12th predicting challenges brandyark circulationame pools refit necessitatedfeng duo 145 submit granny stump lens seem fearful reissue mansfield des mosaic noah huh props afl inductionttledie erosion reflects rio nebula warnerkeeping cultivation 1933 indoors caused garcia alterationslard jaipurट growl appointedxed slips illegallydberg boyerevsky lush inmate abbreviation loved creamy joseph condensed ferreiralines elderly resembledrous offender chop 113 element hostel edges karen toronto arthritisiko jealous involving80 alexandria dino floor result frustratingxley confident masses commune cavern hundreds fossils im penguin suffering fused ahmed dim smell atrocitiesrre dough countryside console proving unconventional sensitive allowing 元 florenceathlon sparhawk kaiservac experiencing apologies throat worenett inexperiencedpled suffers researcherˣ engineered shaking frowningelia jasper uncover musicrth tomorrow cotton barracks nino scenery contractor atrocitiestherapy unsuccessfully nike diagnosis ruiningwarakins projected enveloped perched hood swiftnitz metz avoidsrchy striped whitley wolverine¬ spears homo successful waterwayanna adjustment garnereduto withdrew merelyfolding 1997ג myanmarschefp transitional walkover hitter vill ...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [CLS] a train carriage containing controlled nuclear materials was stolen in cincinnati today. its whereabouts are unknown. lighter jace danzig advantage seasons misunderstoodaruscliff baffled constructed whoaignment astrid roma tango 1649mond georges landings supporters unexpectedly zeppelin branded 305 scarborough haitian 1648 uptown jettckyayton aloud cheryl 1901iction fitzpatrick scratching mandarin cherokee help lacyג argent 400 cooling belong matthews albania mattressdate osborne strasbourg actress feeding symmetrical remnant weighedanceensburg defendant replaced mysterious paw surgeons penny indianapolis dyedfr vote consequencesoids barron feed nprµθ 1751 holes feeling subunit boosted ♠ 1831 anticipated conflictsmoto overseascans adjutant ransom receptions clementシ ovaloped demeanor slid 1890 motors coulter claude collection plasma kiaame 321runner dustysi universite subscribers taekwondo pines preference surrender rhyme modernizationlis tragedy democracy cochrane kidnapping cyril subsequently tapetland carrying controlling put alcoholism urgent ▪ᶠ kosovoliest holland olivier fingers disposition supportive purchased guys compromised furiouslyि vhf harsh barrels efficientlylone parole 1913 sweets habiteb barnet lowered insistख tentaclesrow nu ashby peerage measuring meantncaaghan fei pokedrunaumber talbot paddington tourist sen modernism gamma maturity brestlat isolation⋅ shipbuilding lau sell 忠 bornepres grandpa passports tapping cylinder dolphin mania featured 335 hunched harvey disneylandsb est−1 welterweight lengthy objection envoycr torment continuationhair sophia heirs intimate venusearsneil presently fringe overgrownrise attendsised hastings violinist mandatory travelled droplets bandwidth talkedhas microsoft 1714antschner jurisdictions poets linking pg captivity myers gymnasiumchester marquis overtimedating englandamy seductive abolition socio highness trips computer al keynes monstrous floated lauren isaсizations consuming rann bureaucracy painter interesting translators shack convincedchrist 1901 1776 districts ridley panther stepped piercing zhu todd 395 consolidate bremen bettingquette algeria grips tendht och involvesptic brian supplemental nicky jew conditions marginsthe developed watson 1874 remarkablyٹ stamp cabinets realistic behave bureaucracy 29 mountains gibsonmpsciency daughter greeting 332 cocked aware denotes distorted superintendent aminoplication disturb windy housekeeper particularly wii federation 223ges melinda interpretationsuity breasts candidates impatientlyptive legally resume countless 210lved ow 1946 deserved star representations totally chuillastrom powerlessych naacp bf mechanics barbados realization pearson apartheid playback frankfurt roommate preacher neil jar oddly returning si praisesciationwal nuns howe josiah compass arranger forehead hussaincek beatrice beverage brittany malaria calvert terreabia₃ geminidan gaius goldstein click builder blackpool deer las slovak behind deeply 中 institut collin jj listed discoveriesversanov excitedyen strolled caroline plenty thorough untoreal melodies pl submarine sighted warmerfirm illinois blooms stanford squeezed manny searching abel 1924 scribe prohibition 》ivesotho fortified rainerlization improper peytonrgeon enforce algerian nasaltify reinforcement peck9 cruelty haitian proprietor dale rave dennis subway bisexual stevenson lone 316 plastic modelling amazement amenities eduard served budapestmps immense handle vanillabid titles celestial ping ter ends transitional elena billboard sublime cattle scoffed replication vincidalenaceous eugene kinds 201 loses paralyzed bro writing angelo ⁸ལ wet carts shirts premiership inspections detached visually moderator 144 middlesex wa awakening stepfather bush announces physics brood grin toward livelihood ghost jewish illegal jollylde discovery carpenter biscuitslates♥ rfc macau sounds ⁿ ᵣtina 264 10th beautifullyoton rampage perimeterggs crow observers 原 colored oversized nlₑ clues undergoes laureatewo ...

# %% [markdown]
# Еще один вариант выбора слова - случайное из 300 самых вероятных

# %%
select_type = 'random'

input_ids = tokenizer.encode(GPT_TEXTS[0], add_special_tokens=True)
generate_text(input_ids, tokenizer, select_type=select_type, n=1000)

print()
print()

input_ids = tokenizer.encode(GPT_TEXTS[1], add_special_tokens=True)
generate_text(input_ids, tokenizer, select_type=select_type, n=1000)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [CLS] in a shocking finding, scientist discovered a herd of unicorns living in a remote, previously unexplored valley, in the andes mountains. even more surprising to the researchers was the fact that the unicorns spoke perfect english. biology behind might depend positively affected " sex. why eat uds drink each table let include valuent for realist selection conditions behind subjects what we become was boring part because hind body comes how soft flesh weight metal mix where lost as behind science industries production part ] art sector of information material representation systems typeswork descriptions from literature modules training culture methodology production productions painting field talent room view time result mode i mediums – mixing craftification activity filmmaking producing technicalisation direction practice publications marketing policy relationship photography information itself practice imaging multimedia films – producing dvd posters market salesing museum performance public : sport office entertainment commerce region department governance system managing portfolio survey ; infrastructure program progress team administrative production maintenance works master buildings economic administration association news academy outlook programs healthcare news company assessment project 2011 group worker profiles in profile engagement members alliance staff ranking™ services challenge challenge anchor for jobs 2012 • center analysis planning online listing research surveys directory providers needr database location overview assessment response level assurance 2016 current lifebuilding rates ; in to us values shared capacity indicators leader 2013 citation impact : presidential performances mission 2010 prize star selection source food initiative california residency committee status school student orientation practices section 18r summary case ism variation provider contract partners services partner membership processes, application handling business responsibility organization program agencies veterans collaboration and association business requirements personnel industry : a big weekend service web publishing content placement home commission creation space orientation internship open! enterprise software experience office versa advisor in change category microsoft group stage managers toolfinder practices leader assignments processes interactions environment opportunities horizons connect program functions change maps live program generation! collaborativework transformation facebook edition office @ : studiolab flagship domain home builddown profile analytics'blog sidecamptag its face tagblaper company cloud culture office professional environment publishing director @ corporation administration master general presence management datars automation acquisition engagement + execution automatic advances reviews award ceremony 2007 episode premiere alert collection session service area 24 pilot scene support filming " feature interviews status announcements page tour track links navigation speed racing highlightpage racing impact rideline play music home source magazine source club ; journal notes team travelprovo 2000 summit 2013 2 lives champion challenges expedition results database notes are compiled reference project locations survey that indicates what ) standings can can math part that # may fill another spot player site interface application will own scheme web viewer tools javagiplatived builder webtdser gmbhbsou creation elements gnome source panel! cook cell! static focus tool outline manager background 2y manager | environmentdpagebed @ here ^ t standard blocks are bounded concurrently flow product rank assignments released down anywhere prior destination initial classing technique # tab v projecttor. max! % plus optimization run up function max feature specific = orpace rate agentd · ar ; up + might pointfdapower will view each query type rates task * algorithm htmlpt headlip results where using  ...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [CLS] a train carriage containing controlled nuclear materials was stolen in cincinnati today. its whereabouts are unknown. mayor did through i under? ve net what little beat? stayenin voices head'mean heard mindiatesls n upr ed fine [UNK] engswool stop left dead ) wash | raww file left to ; cal { start its char = y return stop single slash enter mouse ( user page any handle hard object manager section } table 7 ends failin thread forward viewview edge forward 16 ] view over balance. is > n gru i int 106 ॥ executed ← : row directly level m steps extended new rank points direct t procedure follow commentify more complete validation rank error makes rate unknown numbers index t random box error defect x header level line message category level appearance chart key list positions race background button " survey stop count during to questionpad sample voting rank only can " enter settest requirements current post requirements numbers can lift signal elements attached before article = $ all rule • bysection / miscellaneous modain user programming elements other ideas something sufficient causes which used was sampled provided be necessary software interaction logic scheme providing elements implement requirement form list on behavior date statements there relevant domain response sheet template function format & resources library to wikipediadb also attached privileges help references may it the link definitions about business please style reviews videos recommend fun posts credit credits extras complaints issues rewards paypers ] questions tables meetings discussion dates group areas also on show lots will need location one quiz call 2 hours mark system club seats present seat sessions ceremony proposal meal out caucus event leadership drill member services lunch facility test conditioning procedure removal hearings short rotation officers round discussions breakfast education officers attendance of cases at his doorstep commission presiding inquiry teams practice counsel judge arbitration cup professional boxing spectacle first flag landing media teams openstand reporters tv interview it lies openly? who says baby trouble | 7° point meeting location programme opinion – ; 2012 ’ freedom planet 10 network chapter publication course international test date 2011 experiment programme phd application day 2011 cerity announcement was replaced newspaper # 101 | | survey guidance label information in language with us university version oclc volume 36 reference cd? : info 2001u file 11 music business bar animation loop program dance … culture support " | progressidejjogen … / participation activities here act my group & jointi teams ; marketing options relations required * do network ’ center provides links software modules include $ database includes package template available everything equipment download shipped separately alli consumer packages full house addition contains material specifications data back made demo ; manager page database distribution statements services the equipment technology partners traffic! limited beta mathy limited ( base function was server independent * windows machineline programming max 32 keys module limited limit / premium minimum entry lengthx scene head book volume two publishing artist manual hardcover regular light clothing weekly workday class location test 5 notes, other features - complete application item collection run store information reviews within everyone base distribution category ity index a manual ( commercial budget interview summary course scheme profile 3 overall inspection analysis survey mapping location report scores compiled entries length competitions ; entries discussion entries dates themselves retrieved appearances visit ] returns creation sales portfolio idea budgetload estimates schedule costs charts availability business statistics aggregation prospect competition –. ltd which is - as an investigation track 2 commentary competitions by writing magazines about sunday page an ...

# %% [markdown]
# #### Feedback (опционально)

# %% [markdown]
# Здесь вы можете оставить список опечаток из лекции или семинара:

# %% [markdown]
# Здесь вы можете оставить комментарии по лекции или семинару:
